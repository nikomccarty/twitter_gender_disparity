# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('twitter2018_Werner_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  avg_orig_message_likes  avg_orig_message_retweets  \
# 0           0                3.090909                   2.303030
# 1           1                6.733333                   2.600000
# 2           2                1.500000                   0.000000
# 3           3                5.432531                   3.250627
# 4           4                1.000000                   1.000000
#
#    friends_count  followers_count  female_pct_follower  female_pct_friend  \
# 0           19.0             84.0             0.654321           0.368421
# 1          295.0            213.0             0.547264           0.527211
# 2           14.0              0.0                  NaN           0.571429
# 3          569.0           1637.0             0.384262           0.388693
# 4           85.0             61.0             0.333333           0.269231
#
#    twitter  female  asstprof  assocprof  prof  academic  yrs_on_twitter  \
# ...

# %%
df.fillna(np.nan, inplace=True)

# %%
df.head(10)
# Out:
#    Unnamed: 0  avg_orig_message_likes  avg_orig_message_retweets  \
# 0           0                3.090909                   2.303030
# 1           1                6.733333                   2.600000
# 2           2                1.500000                   0.000000
# 3           3                5.432531                   3.250627
# 4           4                1.000000                   1.000000
# 5           5                8.166667                   3.041667
# 6           6                6.947368                   4.760000
# 7           7                2.968750                   1.615385
# 8           8                4.777778                   2.000000
# 9           9                7.633333                   4.565217
#
#    friends_count  followers_count  female_pct_follower  female_pct_friend  \
# 0           19.0             84.0             0.654321           0.368421
# 1          295.0            213.0             0.547264           0.527211
# ...

# %%
df = df.rename(columns={"Unnamed: 0": "id"})

# %%
df.tail()
# Out:
#       id  avg_orig_message_likes  avg_orig_message_retweets  friends_count  \
# 914  914               42.222222                   5.500000         1020.0
# 915  915                9.934827                   6.125257          596.0
# 916  916               11.139535                   5.125000          335.0
# 917  917               26.360965                  32.502075         2507.0
# 918  918                1.904762                   1.761905           76.0
#
#      followers_count  female_pct_follower  female_pct_friend  twitter  female  \
# 914            311.0             0.837662           0.836735      1.0     1.0
# 915           5885.0             0.322319           0.467116      1.0     0.0
# 916            361.0             0.674286           0.657576      1.0     1.0
# 917          22160.0             0.335281           0.314053      1.0     0.0
# 918            105.0             0.222222           0.302632      1.0     0.0
#
# ...

# %%
df.to_csv('twitter2018_Werner_data_clean.csv')
